# %%
import pandas as pd 
import numpy as np

df=pd.read_csv('/Users/lambardaar/Desktop/STUDY/python/ml/class_practice/dataset/titanic.csv')
df.head(4)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
# 3          895         0       3                  Wirz, Mr. Albert    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q
# 3  27.0      0      0  315154  8.6625   NaN        S

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB
# (418, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Survived',data=df,hue='Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
embark=pd.get_dummies(df['Embarked'],drop_first=True,dtype=int)
embark.head()
sex=pd.get_dummies(df['Sex'],drop_first=True,dtype=int)
sex.head()
pcl=pd.get_dummies(df['Pclass'],drop_first=True,dtype=int)
pcl.head()
# Out:
#    2  3
# 0  0  1
# 1  0  1
# 2  1  0
# 3  0  1
# 4  0  1

# %%
df=pd.concat([df,sex,pcl,embark])
df.drop
# Out:
# <bound method DataFrame.drop of      PassengerId  Survived  Pclass  \
# 0          892.0       0.0     3.0
# 1          893.0       1.0     3.0
# 2          894.0       0.0     2.0
# 3          895.0       0.0     3.0
# 4          896.0       1.0     3.0
# ..           ...       ...     ...
# 413          NaN       NaN     NaN
# 414          NaN       NaN     NaN
# 415          NaN       NaN     NaN
# 416          NaN       NaN     NaN
# 417          NaN       NaN     NaN
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5    0.0    0.0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0    1.0    0.0
# 2                       Myles, Mr. Thomas Francis    male  62.0    0.0    0.0
# 3                                Wirz, Mr. Albert    male  27.0    0.0    0.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0    1.0    1.0
# ...

# %%
import pandas as pd 
import numpy as np

df=pd.read_csv('/Users/lambardaar/Desktop/STUDY/python/ml/class_practice/dataset/intrusion_detection_data.csv')
df.head(4)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 4
#       1 import pandas as pd
#       2 import numpy as np
# ----> 4 df=pd.read_csv('/Users/lambardaar/Desktop/STUDY/python/ml/class_practice/dataset/intrusion_detection_data.csv')
#       5 df.head(4)
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.columns.unique().sum()
#
# AttributeError: 'Index' object has no attribute 'sum'
